# %%
import os
import pandas as pd

# %%
df = pd.read_csv("test.csv",  dtype='unicode')

# %%
df1 = pd.read_csv("train.csv",  dtype='unicode')

# %%
df2 = pd.merge(df, df1, how='outer')

# %%
df2
# Out:
#              ID Customer_ID      Month             Name  Age          SSN  \
# 0        0x160a   CUS_0xd40  September    Aaron Maashoh   23  821-00-0265
# 1        0x160b   CUS_0xd40    October    Aaron Maashoh   24  821-00-0265
# 2        0x160c   CUS_0xd40   November    Aaron Maashoh   24  821-00-0265
# 3        0x160d   CUS_0xd40   December    Aaron Maashoh  24_  821-00-0265
# 4        0x1616  CUS_0x21b1  September  Rick Rothackerj   28  004-07-5839
# ...         ...         ...        ...              ...  ...          ...
# 149995  0x25fe9  CUS_0x942c      April            Nicks   25  078-73-5990
# 149996  0x25fea  CUS_0x942c        May            Nicks   25  078-73-5990
# 149997  0x25feb  CUS_0x942c       June            Nicks   25  078-73-5990
# 149998  0x25fec  CUS_0x942c       July            Nicks   25  078-73-5990
# 149999  0x25fed  CUS_0x942c     August            Nicks   25  078-73-5990
#
#        Occupation Annual_Income Monthly_Inhand_Salary Num_Bank_Accounts  ...  \
# ...

# %%
df2.to_csv('final.csv')

# %%
df3 = pd.read_csv("final.csv", dtype='unicode')

# %%
df3
# Out:
#        Unnamed: 0       ID Customer_ID      Month             Name  Age  \
# 0               0   0x160a   CUS_0xd40  September    Aaron Maashoh   23
# 1               1   0x160b   CUS_0xd40    October    Aaron Maashoh   24
# 2               2   0x160c   CUS_0xd40   November    Aaron Maashoh   24
# 3               3   0x160d   CUS_0xd40   December    Aaron Maashoh  24_
# 4               4   0x1616  CUS_0x21b1  September  Rick Rothackerj   28
# ...           ...      ...         ...        ...              ...  ...
# 149995     149995  0x25fe9  CUS_0x942c      April            Nicks   25
# 149996     149996  0x25fea  CUS_0x942c        May            Nicks   25
# 149997     149997  0x25feb  CUS_0x942c       June            Nicks   25
# 149998     149998  0x25fec  CUS_0x942c       July            Nicks   25
# 149999     149999  0x25fed  CUS_0x942c     August            Nicks   25
#
#                 SSN Occupation Annual_Income Monthly_Inhand_Salary  ...  \
# ...

# %%
print(df3)
# Out:
#        Unnamed: 0       ID Customer_ID      Month             Name  Age  \
# 0               0   0x160a   CUS_0xd40  September    Aaron Maashoh   23
# 1               1   0x160b   CUS_0xd40    October    Aaron Maashoh   24
# 2               2   0x160c   CUS_0xd40   November    Aaron Maashoh   24
# 3               3   0x160d   CUS_0xd40   December    Aaron Maashoh  24_
# 4               4   0x1616  CUS_0x21b1  September  Rick Rothackerj   28
# ...           ...      ...         ...        ...              ...  ...
# 149995     149995  0x25fe9  CUS_0x942c      April            Nicks   25
# 149996     149996  0x25fea  CUS_0x942c        May            Nicks   25
# 149997     149997  0x25feb  CUS_0x942c       June            Nicks   25
# 149998     149998  0x25fec  CUS_0x942c       July            Nicks   25
# 149999     149999  0x25fed  CUS_0x942c     August            Nicks   25
#
#                 SSN Occupation Annual_Income Monthly_Inhand_Salary  ...  \
# ...

# %%
df3.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN',
#        'Occupation', 'Annual_Income', 'Monthly_Inhand_Salary',
#        'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan',
#        'Type_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment',
#        'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Credit_Mix',
#        'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
df3.columns[-1]
# Out:
# 'Credit_Score'

# %%
df3.pop(df3.columns[-1])
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#             ...
# 149995        Poor
# 149996        Poor
# 149997        Poor
# 149998    Standard
# 149999        Poor
# Name: Credit_Score, Length: 150000, dtype: object

# %%
df3
# Out:
#        Unnamed: 0       ID Customer_ID      Month             Name  Age  \
# 0               0   0x160a   CUS_0xd40  September    Aaron Maashoh   23
# 1               1   0x160b   CUS_0xd40    October    Aaron Maashoh   24
# 2               2   0x160c   CUS_0xd40   November    Aaron Maashoh   24
# 3               3   0x160d   CUS_0xd40   December    Aaron Maashoh  24_
# 4               4   0x1616  CUS_0x21b1  September  Rick Rothackerj   28
# ...           ...      ...         ...        ...              ...  ...
# 149995     149995  0x25fe9  CUS_0x942c      April            Nicks   25
# 149996     149996  0x25fea  CUS_0x942c        May            Nicks   25
# 149997     149997  0x25feb  CUS_0x942c       June            Nicks   25
# 149998     149998  0x25fec  CUS_0x942c       July            Nicks   25
# 149999     149999  0x25fed  CUS_0x942c     August            Nicks   25
#
#                 SSN Occupation Annual_Income Monthly_Inhand_Salary  ...  \
# ...

# %%
df3.to_csv('DDA_Dataset.csv')

# %%
df4 = pd.read_csv("DDA_Dataset.csv", dtype='unicode')

# %%
df4
# Out:
#        Unnamed: 0.1 Unnamed: 0       ID Customer_ID      Month  \
# 0                 0          0   0x160a   CUS_0xd40  September
# 1                 1          1   0x160b   CUS_0xd40    October
# 2                 2          2   0x160c   CUS_0xd40   November
# 3                 3          3   0x160d   CUS_0xd40   December
# 4                 4          4   0x1616  CUS_0x21b1  September
# ...             ...        ...      ...         ...        ...
# 149995       149995     149995  0x25fe9  CUS_0x942c      April
# 149996       149996     149996  0x25fea  CUS_0x942c        May
# 149997       149997     149997  0x25feb  CUS_0x942c       June
# 149998       149998     149998  0x25fec  CUS_0x942c       July
# 149999       149999     149999  0x25fed  CUS_0x942c     August
#
#                    Name  Age          SSN Occupation Annual_Income  ...  \
# 0         Aaron Maashoh   23  821-00-0265  Scientist      19114.12  ...
# ...

# %%
df4.pop(df4.columns[1])
# Out:
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#            ...
# 149995    149995
# 149996    149996
# 149997    149997
# 149998    149998
# 149999    149999
# Name: Unnamed: 0, Length: 150000, dtype: object

# %%
df4
# Out:
#        Unnamed: 0.1       ID Customer_ID      Month             Name  Age  \
# 0                 0   0x160a   CUS_0xd40  September    Aaron Maashoh   23
# 1                 1   0x160b   CUS_0xd40    October    Aaron Maashoh   24
# 2                 2   0x160c   CUS_0xd40   November    Aaron Maashoh   24
# 3                 3   0x160d   CUS_0xd40   December    Aaron Maashoh  24_
# 4                 4   0x1616  CUS_0x21b1  September  Rick Rothackerj   28
# ...             ...      ...         ...        ...              ...  ...
# 149995       149995  0x25fe9  CUS_0x942c      April            Nicks   25
# 149996       149996  0x25fea  CUS_0x942c        May            Nicks   25
# 149997       149997  0x25feb  CUS_0x942c       June            Nicks   25
# 149998       149998  0x25fec  CUS_0x942c       July            Nicks   25
# 149999       149999  0x25fed  CUS_0x942c     August            Nicks   25
#
#                 SSN Occupation Annual_Income Monthly_Inhand_Salary  ...  \
# ...

# %%
df4.to_csv("DDA_Final_Dataset.csv")

# %%
df4
# Out:
#        Unnamed: 0.1       ID Customer_ID      Month             Name  Age  \
# 0                 0   0x160a   CUS_0xd40  September    Aaron Maashoh   23
# 1                 1   0x160b   CUS_0xd40    October    Aaron Maashoh   24
# 2                 2   0x160c   CUS_0xd40   November    Aaron Maashoh   24
# 3                 3   0x160d   CUS_0xd40   December    Aaron Maashoh  24_
# 4                 4   0x1616  CUS_0x21b1  September  Rick Rothackerj   28
# ...             ...      ...         ...        ...              ...  ...
# 149995       149995  0x25fe9  CUS_0x942c      April            Nicks   25
# 149996       149996  0x25fea  CUS_0x942c        May            Nicks   25
# 149997       149997  0x25feb  CUS_0x942c       June            Nicks   25
# 149998       149998  0x25fec  CUS_0x942c       July            Nicks   25
# 149999       149999  0x25fed  CUS_0x942c     August            Nicks   25
#
#                 SSN Occupation Annual_Income Monthly_Inhand_Salary  ...  \
# ...
